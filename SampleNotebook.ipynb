# %%
import numpy as np
import seaborn as sb
print('hello world')
# Out:
# hello world

# %% [markdown]
# Markdown cell with text
# A little more text

# %%
sample = np.random.normal(2,0.3,10000)
print(sample)
# Out:
# [1.90194482 2.06344073 2.57640252 ... 2.15348212 1.99791109 1.99331314]

# %%
sb.distplot(sample)
